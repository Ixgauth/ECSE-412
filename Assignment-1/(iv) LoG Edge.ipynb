# %%
import cv2
import numpy as np
import skimage.measure
import matplotlib.pyplot as plt

#intake the image and convert it to RGB
image_path = "woman.png"

image = cv2.imread(image_path)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#perform gaussian filter on the image
image = cv2.GaussianBlur(image, (5,5), 0)

#convert the image to greyscale
image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

#perform laplace filtering on the image
I_lap = cv2.Laplacian(image, cv2.CV_32F, ksize=5)

#convert to 8 bit image to complete edge detection
cv2.convertScaleAbs(I_lap, output)

#display the images
plt.figure(figsize=(20, 20))
plt.subplot(211), plt.imshow(image, cmap="gray")
plt.title("Image"), plt.xticks([]), plt.yticks([])
plt.subplot(212), plt.imshow(output, cmap="gray")
plt.title("I_lap"), plt.xticks([]), plt.yticks([])
plt.show()
